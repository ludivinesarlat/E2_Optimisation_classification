# %%
import sklearn
import numpy as np

import pandas as pd
import datetime
import time
import pickle
import mlflow
import mlflow.sklearn

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                                                    titre jour_publication  \
# 0      Pour les galeries d’art, une situation moins s...       01-02-2021
# 1      Quand la masturbation provoque une hémorragie ...       01-02-2021
# 2      Les pistes de la France pour améliorer les ter...       01-02-2021
# 3        Facebook et Apple se livrent une guerre ouverte       01-02-2021
# 4      Kent Walker : « Google agit selon les lois, et...       01-02-2021
# ...                                                  ...              ...
# 46931  Christina Milian : cet achat complètement impu...       2020/04/01
# 46932  Matt Pokora confiné : il partage une photo tro...       2020/04/01
# 46933  Meghan, Harry et Archie : que font-ils pendant...       2020/04/01
# 46934  Megxit : quels membres de la famille royale su...       2020/04/01
# 46935  Mort de Pape Diouf : Florian Thauvin, Djibril ...       2020/04/01
#
#                       auteur   journal
# 0           ['Roxana Azimi']  Le Monde
# ...

# %%
with mlflow.start_run():
    long = len(df)
    mlflow.log_metric('observation',long)
